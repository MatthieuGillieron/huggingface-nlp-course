# %%
from transformers import BertConfig, BertModel

# Construire la configuration
config = BertConfig()

# Construire le modèle à partir de la configuration
model = BertModel(config)

print(config)

# %% [markdown]
# ```hide_size``` : taille du vecteur (dimension)
# ```hidden_states``` et ```num_hidden_layers``` : nbr de couche que le transfomers possede

# %%
from transformers import BertConfig, BertModel

config = BertConfig()
model = BertModel(config)

# Le modèle est initialisé de façon aléatoire !

# %% [markdown]
# Le modèle peut être utilisé tel quel mais il produira du charabia.

# %%
from transformers import BertModel

model = BertModel.from_pretrained("bert-base-cased")
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %% [markdown]
# il faut charger un transformes qui a deja ete utiliser

# %% [markdown]
# sauvegardeer un modele : ```model.save_pretrained("directory_on_my_computer")```
